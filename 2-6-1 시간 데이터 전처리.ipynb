# %% [markdown]
# ## 1. import dataframe

# %% [markdown]
# ### 1. import libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import time
import datetime
from dateutil.parser import parse
import matplotlib.pyplot as plt

# %% [markdown]
# ## 2. import time series data

# %%
df = pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/a10.csv', parse_dates=['date'])
sample_df = df

# %%
# 숫자를 입력하여 시간 형태로 저장
d = datetime.datetime(2018, 5, 19)
# 데이터를 원하는 형태로 출력
d.strftime('%m-%d-%Y')
# Out:
# '05-19-2018'

# %%
Date = sample_df['date']
sample_df['date'] = Date.dt.strftime('%d-%b-%Y') # 연월일
Date = pd.to_datetime(Date)
sample_df['date'] = Date.dt.strftime('%Y-%m') # 연월일 중 일부만 사용시 pd.to_datetime 변경 후 다시 strftime

# %%
sample_df_1 = sample_df.set_index('date')
sample_df_1['value'].plot(title = 'blah')
# Out:
# <AxesSubplot:title={'center':'blah'}, xlabel='date'>
